# %% [markdown]
# # Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# Matplotlib is a popular Python library used for  visualizations of data .
#
# It is widely used in the fields of data analysis, scientific research, and data visualization due to its versatility and ease of use.also data visualization helps in quick decision making .
#
# you can create various plots, such as 1.line plots, 2.scatter plots, 3.bar plots, 4.histograms, and 5. pie charts.

# %% [markdown]
# # Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %% [markdown]
# Scatter Plot: This plot displays individual data points as markers on a 2D plane. Scatter plots are useful for showing the relationship between two numerical variables.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,)
plt.xlabel("X axis ->")
plt.ylabel("Y axis ->")
plt.title("scatter plot")
# Out:
# Text(0.5, 1.0, 'scatter plot')

# %% [markdown]
# # Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %% [markdown]
# The subplot() function in Matplotlib is used to create multiple plots or subplots within a single figure. It allows you to divide the figure into a grid of rows and columns and specify the position of each subplot within that grid.

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.array([0, 1, 2, 3, 4, 5])

y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])


plt.figure(figsize=(5, 5)) 
plt.subplot(2, 2, 1) 
plt.plot(x, y1, label='Line 1')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Line Plot 1')


plt.subplot(2, 2, 2)  
plt.plot(x, y2, label='Line 2')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Line Plot 2')


plt.subplot(2, 2, 3) 
plt.plot(x, y3, label='Line 3')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Line Plot 3')


plt.subplot(2, 2, 4) 
plt.plot(x, y4, label='Line 4')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Line Plot 4')


plt.tight_layout()  # Optional: Adjust the spacing between subplots for a cleaner layout

# %% [markdown]
# # Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# Bar Plot: A bar plot represents data using rectangular bars of varying lengths or heights. It is commonly used to compare different categories or groups.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
plt.xlabel('company->')
plt.ylabel('profit->')
plt.title('bar plot')
# Out:
# Text(0.5, 1.0, 'bar plot')

# %%
plt.barh(company,profit)
plt.xlabel('profit->')
plt.ylabel('company->')
plt.title('horizontal bar plot')
# Out:
# Text(0.5, 1.0, 'horizontal bar plot')

# %% [markdown]
# # Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %% [markdown]
# A box plot, also known as a box-and-whisker plot, is a graphical representation of the distribution of a dataset.
#
# Box plots are used to Visualize data distribution and Compare multiple datasets

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data = [box1, box2]
plt.boxplot(data, labels=['Box 1', 'Box 2'])
plt.xlabel('Datasets')
plt.ylabel('Values')
plt.title('Box Plot of Two Datasets')
# Out:
# Text(0.5, 1.0, 'Box Plot of Two Datasets')
