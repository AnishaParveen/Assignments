# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_excel('flight_price.xlsx')
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %% [markdown]
# Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the
# dataset have?

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the
# distribution.
#
# ans-> right skewed distribution

# %%
plt.figure(figsize=(10,10))
sns.histplot(df['Price'],kde=True)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %% [markdown]
# Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %% [markdown]
# the range is 1759 to 79512
#
# min=1759
#
# max=79512

# %% [markdown]
# Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.
#
# ans->price of jet airways business airline is very high

# %%
plt.figure(figsize=(30,5))
sns.boxplot(x=df['Airline'],y=df['Price'])
# Out:
# <AxesSubplot: xlabel='Airline', ylabel='Price'>

# %% [markdown]
# Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
# they may impact your analysis.
#
# ans-> yes there is. there is so many outliers we can see from the boxplot like Indigo , Air India and so on flight price. while compareing  Airline vs price we can see that for these tyes of outliers causes a massive change in average flight price.

# %% [markdown]
# Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
# to identify the peak travel season. What features would you analyze to identify the peak season, and how
# would you present your findings to your boss?

# %%
df['month']=df['Date_of_Journey'].str.split('/').str[1].astype(int)

# %%
df.head(1)
# Out:
#   Airline Date_of_Journey    Source Destination      Route Dep_Time  \
# 0  IndiGo      24/03/2019  Banglore   New Delhi  BLR → DEL    22:20
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  month
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897      3

# %%
df['month'].unique()
# Out:
# array([3, 5, 6, 4])

# %%
sns.histplot(df['month'])
# Out:
# <AxesSubplot: xlabel='month', ylabel='Count'>

# %% [markdown]
# we can see from the analysis the peak season of travelling is in the month of may & june.

# %% [markdown]
# Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
# Price dataset to identify any trends in flight prices. What features would you analyze to identify these
# trends, and what visualizations would you use to present your findings to your team?
#
# ans->To analyze trends in flight prices for a flight booking website:
#
# 1. Examine time trends .
#
# 2. Analyze price variations .
#
# 3. Compare airline prices .
#
# 4. Explore the impact of the number of stops on prices using box plots or bar charts.
#
# 5. Assess the relationship between flight duration and prices.
#
# 6. Visualize price distributions using histograms.

# %%
df['time_in_minutes'] = pd.to_timedelta(df['Duration'], errors='coerce').dt.total_seconds() / 60
df.head(1)
# Out:
#   Airline Date_of_Journey    Source Destination      Route Dep_Time  \
# 0  IndiGo      24/03/2019  Banglore   New Delhi  BLR → DEL    22:20
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897      3
#
#    time_in_minutes
# 0            170.0

# %%
sns.scatterplot(x=df['time_in_minutes'],y=df['Price'])
# Out:
# <AxesSubplot: xlabel='time_in_minutes', ylabel='Price'>

# %%
df['Total_Stops']=df['Total_Stops'].map({'non-stop':0, '2 stops':2, '1 stop':1, '3 stops':3, np.nan:1, '4 stops':4})

# %%
sns.scatterplot(x=df['Total_Stops'],y=df['Price'])
# Out:
# <AxesSubplot: xlabel='Total_Stops', ylabel='Price'>

# %%
sns.histplot(df['Price'])
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %% [markdown]
# Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
# Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
# identify these factors, and how would you present your findings to the management team?
#
# ans->Features to Analyze:Route,Airline,Number of Stops,Time Factors (Departure Time, Arrival Time),Day of the Week,Flight Duration.
#
# Presentation:
# Using visualizations (bar charts, box plots, scatter plots) to illustrate findings.
# Highlight key insights and their implications.
# Provide statistical analysis if relevant.

# %% [markdown]
# Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
# the dataset have?

# %%
df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# %%
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
# app categories.

# %%
plt.figure(figsize=(12, 10))
sns.boxplot(data=df,y='Category',x='Rating')
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Category'>

# %% [markdown]
# Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
# impact your analysis.
#
# ans->yes, Missing values can affect the accuracy and reliability of your analysis, introduce bias, and affect statistical measures and data visualizations.

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
# the relationship.

# %%
df['Size']=df['Size'].str.replace('M','000')
df['Size']=df['Size'].str.replace('k','')
df['Size']=df['Size'].replace('Varies with device',np.nan)
df['Size']=df['Size'].str.replace('+','')
df['Size']=df['Size'].str.replace(',','')
df['Size']=df['Size'].astype(float)
# Out:
# /tmp/ipykernel_4273/1836760660.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Size']=df['Size'].str.replace('+','')

# %%
plt.figure(figsize=(30, 15))
sns.scatterplot(x=df['Rating'],y=df['Size'])
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Size'>

# %% [markdown]
# Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
df['Price']=df['Price'].str.replace("$","")
df['Price']=df['Price'].str.replace('Everyone',"0")
# Out:
# /tmp/ipykernel_4273/2204740275.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price']=df['Price'].str.replace("$","")

# %%
df['Price']=df['Price'].str.split('.').str[0].astype(int)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size     Installs  Type  Price Content Rating  \
# 0     159  19000.0      10,000+  Free    0.0       Everyone
# 1     967  14000.0     500,000+  Free    0.0       Everyone
# 2   87510      8.7   5,000,000+  Free    0.0       Everyone
# 3  215644  25000.0  50,000,000+  Free    0.0           Teen
# 4     967      2.8     100,000+  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Type']=df['Type'].replace('0','Free')

# %%
sns.barplot(x=df['Type'],y=df['Price'])
# Out:
# <AxesSubplot: xlabel='Type', ylabel='Price'>

# %% [markdown]
# Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
# with the highest number of installs.

# %%
category = pd.DataFrame(df['Installs'].value_counts())  
category.rename(columns = {'Installs':'Count'},inplace=True)

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=category.index[:10], y ='Count',data = category[:10],palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
popular=df[df['Installs']>1400 ]
popular[popular['Rating']>4.8][0:10]
# Out:
#                                                     App             Category  \
# 55    Tickets SDA 2018 and Exam from the State Traff...    AUTO_AND_VEHICLES
# 61                       CDL Practice Test 2018 Edition    AUTO_AND_VEHICLES
# 64                DMV Permit Practice Test 2018 Edition    AUTO_AND_VEHICLES
# 79                              Tickets + PDA 2018 Exam    AUTO_AND_VEHICLES
# 99                       ipsy: Makeup, Beauty, and Tips               BEAUTY
# 177            eBoox new: Reader for fb2 epub zip books  BOOKS_AND_REFERENCE
# 618                                      FREE LIVE TALK               DATING
# 712      Learn Japanese, Korean, Chinese Offline & Free            EDUCATION
# 1258           Lose Belly Fat in 30 Days - Flat Stomach   HEALTH_AND_FITNESS
# 1260                  Six Pack in 30 Days - Abs Workout   HEALTH_AND_FITNESS
#
#       Rating Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %% [markdown]
# Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
# Google Playstore dataset to identify the most popular app categories. How would you approach this
# task, and what features would you analyze to make recommendations to the company?
#
# ans->to help the company identify the most popular app categories for their new app on the Google Play Store:
#
# 1. Load and explore the dataset.
# 2. Define what "popularity" means (e.g., installs, ratings).
# 3. Analyze app categories based on popularity metrics.
# 4. Visualize the data for easy understanding.
# 5. Consider user reviews and sentiments.

# %%
category = pd.DataFrame(df['Category'].value_counts())        
category.rename(columns = {'Category':'Count'},inplace=True)
plt.figure(figsize=(15,6))
sns.barplot(x=category.index[:10], y ='Count',data = category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the
# most successful app developers. What features would you analyze to make recommendations to the
# company, and what data visualizations would you use to present your findings?
#
# ans->To identify the most successful app developers in the Google Play Store dataset:
#
# **Features to Analyze:**
# - Number of installations
# - Average user ratings
# - Number of apps published
# - App categories
# - User reviews and sentiment
#
# **Data Visualizations:**
# - Bar charts for comparisons
# - Scatter plots for ratings vs. installations
# - Pie charts for category distribution

# %% [markdown]
# Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to
# launch a new app. What features would you analyze to make recommendations to the company, and
# what data visualizations would you use to present your findings?
#
# ans->To identify the best time to launch a new app in the Google Play Store for a marketing research firm:
#
# **Features to Analyze:**
# - App release dates
# - Downloads and installations
# - Ratings and reviews
#
#
# **Data Visualizations:**
# - Time series line charts
# - Heatmaps
# - Bar charts
# - Scatter plots
# - Box plots
#
# **Recommendations:**
# - Analyze historical data to find trends.
# - Consider lower competition periods.
# - Account for seasonality and market events.
# - Balance peak and off-peak launch times.
# - Validate findings with additional research.
