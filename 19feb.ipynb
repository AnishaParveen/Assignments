# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?
#
# ans->Flask is a web framework that provides libraries to build lightweight web applications in python.
#
# Some benefits of using the Flask framework are:
#
# 1.It has an inbuilt development server.
#
# 2.It has vast third-party extensions.
#
# 3.It has a tiny API and can be quickly learned by a web developer.
#
# 4.It is WSGI compliant.
#
# 5.It supports Unicode.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
from flask import Flask
app=Flask(__name__)
@app.route("/")
def display():
    return "Hello World!!"
if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot (2).png](attachment:dde25b79-5a47-4ca3-8f8b-350d9959406d.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?
#
# ans->App Routing means mapping the URLs to a specific function that will handle the logic for that URL. Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler. Example: In our application, the URL (“/”) is associated with the root URL.
#
# App routing is used to map the specific URL with the associated function that is intended to perform some task. It is used to access some particular page like Flask Tutorial in the web application.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %%
from flask import Flask
app=Flask(__name__)


@app.route("/welcome")
def welcome():
    return "Welcome to ABC Corporation"

@app.route("/")
def details():
       company_name = 'ABC Corporation'
       location = 'India'
       contact_detail = '999-999-9999'
       return f'Company Name: {company_name}<br>Location: {location}<br>Contact Detail: {contact_detail}'

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot (3)-min.png](attachment:8f74de31-2b85-46e4-815a-b787e005a2a1.png)

# %% [markdown]
# ![Screenshot (4)-min.png](attachment:68d5ea16-0780-404f-824f-92c1c9ef8ed2.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.
#
# ans->The url_for() function is used to build a URL to the specific function dynamically. The first argument is the name of the specified function, and then we can pass any number of keyword argument corresponding to the variable part of the URL.

# %%
from flask import *  
   
app = Flask(__name__)  
  
@app.route('/admin')  
def admin():  
    return 'admin'  
   
  
@app.route('/student')  
def student():  
    return 'student'  
  

@app.route('/user/<name>')  
def user(name):  
    if name == 'admin':  
        return redirect(url_for('admin'))  
      
    if name == 'student':  
        return redirect(url_for('student'))  

if __name__ =='__main__':  
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot (7)-min.png](attachment:2c33adb1-2508-4948-bc32-90682ae110fc.png)

# %% [markdown]
# ![Screenshot (8)-min.png](attachment:3dd05fdc-4f6c-433c-a9a1-3f730f33e1a6.png)
